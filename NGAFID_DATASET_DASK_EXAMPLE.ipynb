# %% [markdown]
# <a href="https://colab.research.google.com/github/LoganKon/NGAFIDDATASET/blob/main/NGAFID_DATASET_DASK_EXAMPLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INSTALL PREREQ

# %%
# !python -m pip install "dask[dataframe]"

# %%
# !git clone https://github.com/LoganKon/NGAFIDDATASET.git

!(cd NGAFIDDATASET ; git checkout main; git reset --hard HEAD; git pull)
!(cd NGAFIDDATASET ; pip install -r requirements.txt -q)
# Out:
# fatal: destination path 'NGAFIDDATASET' already exists and is not an empty directory.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# HEAD is now at 3ee0c14 Update dataset.py
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1.14 KiB | 583.00 KiB/s, done.
# From https://github.com/LoganKon/NGAFIDDATASET
#    3ee0c14..dee60a3  main       -> origin/main
# Updating 3ee0c14..dee60a3
# Fast-forward
#  ngafiddataset/dataset/dataset.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %% [markdown]
# # IMPORT DEPENDENCIES

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('/content/NGAFIDDATASET')

# %%
# %autoreload
from ngafiddataset.dataset.dataset import NGAFID_Dataset_Manager

import pandas as pd


_ = NGAFID_Dataset_Manager('all_flights')
# Out:
# 2025-02-25 06:37:39.424 | INFO     | ngafiddataset.dataset.dataset:__init__:56 - Downloading and extracting Parquet Files to \one_parq.  Please open them using dask dataframes
# 2025-02-25 06:37:39.425 | INFO     | ngafiddataset.dataset.dataset:download:41 - Extracting File

# %%
import tarfile

# 设定 .tar.gz 文件路径
file_path = '/content/all_flights.tar.gz'

# 打开并解压到 /content 文件夹
with tarfile.open(file_path, 'w:gz') as tar:
    tar.extractall(path='/content/all_flights')

print('解压完成')

import os

# 列出 /content 文件夹中的所有文件
files = os.listdir('/content/all_flights')
print(files)
# Out:
# 解压完成
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-707419ca79ae> in <cell line: 0>()
#      13
#      14 # 列出 /content 文件夹中的所有文件
# ---> 15 files = os.listdir('/content/all_flights')
#      16 print(files)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/all_flights'

# %%
import dask.dataframe as dd

#flight_data_df = dd.read_parquet('content/all_flights/one_parq')

flight_header_df = pd.read_csv('content/all_flights/flight_header.csv', index_col = 'Master Index')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-ff7f6e3e66ec> in <cell line: 0>()
#       3 #flight_data_df = dd.read_parquet('content/all_flights/one_parq')
#       4
# ----> 5 flight_header_df = pd.read_csv('content/all_flights/flight_header.csv', index_col = 'Master Index')
#
# ...

# %%
flight_data_df
# Out:
# Dask DataFrame Structure:
#                    volt1    volt2     amp1     amp2    FQtyL    FQtyR E1 FFlow  E1 OilT  E1 OilP   E1 RPM  E1 CHT1  E1 CHT2  E1 CHT3  E1 CHT4  E1 EGT1  E1 EGT2  E1 EGT3  E1 EGT4      OAT      IAS     VSpd   NormAc   AltMSL timestep cluster
# npartitions=401
# 1                float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64    int64  object
# 103                  ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...     ...
# ...

# %%
flight_data_df.head(5)
# Out:
#               volt1  volt2  amp1  amp2  FQtyL  FQtyR  E1 FFlow  E1 OilT  \
# Master Index
# 1              28.8    NaN   0.8   NaN  48.89  44.06     13.28   168.55
# 1              28.8    NaN   0.8   NaN  48.93  44.06     13.31   168.60
# 1              28.8    NaN   0.9   NaN  48.96  44.06     13.36   168.65
# 1              28.8    NaN   0.7   NaN  48.86  44.06     13.30   168.64
# 1              28.8    NaN   0.6   NaN  48.87  44.06     13.30   168.65
#
#               E1 OilP  E1 RPM  ...  E1 EGT2  E1 EGT3  E1 EGT4   OAT     IAS  \
# Master Index                   ...
# 1               82.51  2519.7  ...  1317.44  1298.97  1322.83  12.8  144.89
# 1               82.51  2519.4  ...  1316.64  1300.68  1322.15  12.8  144.53
# 1               82.51  2520.3  ...  1317.20  1301.05  1323.12  12.8  144.15
# 1               82.51  2519.3  ...  1317.73  1302.14  1321.93  12.8  143.79
# 1               82.51  2518.8  ...  1318.00  1308.52  1316.99  12.8  143.45
#
# ...

# %%
flight_header_df.head(5)
# Out:
#              before_after  date_diff  flight_length  \
# Master Index
# 1                  before         -1         4723.0
# 2                  before         -2         4649.0
# 3                    same          0           40.0
# 4                  before          0           14.0
# 5                    same          0          683.0
#
#                                   label hierarchy  number_flights_before
# Master Index
# 1             intake gasket leak/damage       NaN                      0
# 2             intake gasket leak/damage       NaN                      3
# 3             intake gasket leak/damage       NaN                     -1
# 4             intake gasket leak/damage       NaN                      0
# 5             intake gasket leak/damage       NaN                     -1
